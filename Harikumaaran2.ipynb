# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
ads = pd.read_csv('Social_Network_Ads.csv')

# %%
ads
# Out:
#         User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510.0    Male  19.0          19000.0        0.0
# 1    15810944.0    Male  35.0          20000.0        0.0
# 2    15668575.0  Female  26.0          43000.0        0.0
# 3    15603246.0  Female  27.0          57000.0        0.0
# 4    15804002.0    Male  19.0          76000.0        0.0
# ..          ...     ...   ...              ...        ...
# 395  15691863.0  Female  46.0          41000.0        1.0
# 396  15706071.0    Male  51.0          23000.0        1.0
# 397  15654296.0  Female  50.0          20000.0        1.0
# 398  15755018.0    Male  36.0          33000.0        0.0
# 399  15594041.0  Female  49.0          36000.0        1.0
#
# [400 rows x 5 columns]

# %%
ads.head()
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0  15624510.0    Male  19.0          19000.0        0.0
# 1  15810944.0    Male  35.0          20000.0        0.0
# 2  15668575.0  Female  26.0          43000.0        0.0
# 3  15603246.0  Female  27.0          57000.0        0.0
# 4  15804002.0    Male  19.0          76000.0        0.0

# %%
ads.tail()
# Out:
#         User ID  Gender   Age  EstimatedSalary  Purchased
# 395  15691863.0  Female  46.0          41000.0        1.0
# 396  15706071.0    Male  51.0          23000.0        1.0
# 397  15654296.0  Female  50.0          20000.0        1.0
# 398  15755018.0    Male  36.0          33000.0        0.0
# 399  15594041.0  Female  49.0          36000.0        1.0

# %%
type(ads)
# Out:
# pandas.core.frame.DataFrame

# %%
ads.index
# Out:
# RangeIndex(start=0, stop=400, step=1)

# %%
ads.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
ads.values
# Out:
# array([[15624510.0, 'Male', 19.0, 19000.0, 0.0],
#        [15810944.0, 'Male', 35.0, 20000.0, 0.0],
#        [15668575.0, 'Female', 26.0, 43000.0, 0.0],
#        ...,
#        [15654296.0, 'Female', 50.0, 20000.0, 1.0],
#        [15755018.0, 'Male', 36.0, 33000.0, 0.0],
#        [15594041.0, 'Female', 49.0, 36000.0, 1.0]], dtype=object)

# %%
ads.shape
# Out:
# (400, 5)

# %%
ads.ndim
# Out:
# 2

# %%
ads.size
# Out:
# 2000

# %%
ads['EstimatedSalary'].max()
# Out:
# 150000.0

# %%
# To see how many are of age above 50
ads_age = ads[ads['Age']>50]
ads_salary = ads[ads['EstimatedSalary']>=150000]
print(ads_age)
print(ads_salary)

# %%
ads_salary.count()  # persons with EstimatedSalary > 150000

# %%
ads_age.count()   # persons with age > 50

# %%
ads.isnull().sum()
# Out:
# User ID            27
# Gender             36
# Age                30
# EstimatedSalary    16
# Purchased          11
# dtype: int64

# %%
ads = ads.fillna(ads.mode().iloc[0])  # filling all the nan values by mode of the respective columns

# %%
ads.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
ads.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.568399e+07   37.715000     69272.500000    0.345000
# std    7.568783e+04   10.137589     33468.022276    0.475964
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.561436e+07   31.000000     43000.000000    0.000000
# 50%    1.568544e+07   36.500000     71000.000000    0.000000
# 75%    1.574706e+07   45.000000     86000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
sns.heatmap(ads.corr())

# %%
sns.jointplot(x='Age',y='EstimatedSalary',data=ads,kind='hex')

# %%
sns.pairplot(ads)

# %%
sns.distplot(ads['EstimatedSalary'])  # Most people had their estimated salary below 1 lakh
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot('Gender',data=ads)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(y='EstimatedSalary',x='Gender',data=ads)

# %%
sns.boxplot('Gender','EstimatedSalary', data=ads)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
